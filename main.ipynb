# %%
from ultralytics import YOLO

# Load a model
model = YOLO("yolov8n.yaml")  # build a new model from scratch

# Use the model
results = model.train(data="Garbage collection.yolov8/data.yaml", epochs=75)  # train the model
# Out:
# Ultralytics 8.4.61  Python-3.13.9 torch-2.12.0+cpu CPU (13th Gen Intel Core i5-13450HX)
# ...
